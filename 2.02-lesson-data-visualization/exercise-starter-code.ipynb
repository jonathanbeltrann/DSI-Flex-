# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Python Data Visualization Practice
#
# Practice plotting with `matplotlib`.

# %% [markdown]
# **1. Import the usual data science libraries.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **2. Read the sports dataset (`./data/sports.csv`) into a DataFrame.**
#
# The data is from [this source](https://news.gallup.com/poll/4735/sports.aspx#1) and contains information on the percent of people who say various sports are their favorite to watch.

# %%
sports = pd.read_csv('./data/sports.csv')

# %% [markdown]
# **3. Take a peak and get basic information about the dataset.**

# %%
sports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                7 non-null      int64
#  1   Football            7 non-null      int64
#  2   Basketball          7 non-null      int64
#  3   Baseball            7 non-null      int64
#  4   Soccer              7 non-null      int64
#  5   Ice hockey          7 non-null      int64
#  6   Auto racing         7 non-null      int64
#  7   Tennis              7 non-null      int64
#  8   Golf                7 non-null      int64
#  9   Volleyball          7 non-null      int64
#  10  Boxing              7 non-null      int64
#  11  Gymnastics          7 non-null      int64
#  12  Motocross           7 non-null      int64
#  13  Ice/Figure skating  7 non-null      int64
#  14  Rodeo               7 non-null      int64
#  15  Track and field     7 non-null      int64
#  16  Fishing             7 non-null      int64
#  17  Swimming            7 non-null      int64
#  18  Wrestling           7 non-null      int64
#  19  Bowling             7 non-null      int64
#  20  Other               7 non-null      int64
#  21  None                7 non-null      int64
#  22  No opinion          7 non-null      int64
# dtypes: int64(23)
# memory usage: 1.4 KB

# %%
sports.head()
# Out:
#    Year  Football  Basketball  Baseball  Soccer  Ice hockey  Auto racing  \
# 0  2017        37          11         9       7           4            2
# 1  2013        39          12        14       4           3            2
# 2  2008        41           9        10       3           4            3
# 3  2007        43          11        13       2           4            3
# 4  2006        43          12        11       2           2            4
#
#    Tennis  Golf  Volleyball  ...  Ice/Figure skating  Rodeo  Track and field  \
# 0       2     1           1  ...                   1      0                0
# 1       3     2           0  ...                   1      0                1
# 2       1     2           1  ...                   1      0                0
# 3       1     2           0  ...                   2      0                0
# 4       1     3           0  ...                   3      0                0
#
#    Fishing  Swimming  Wrestling  Bowling  Other  None  No opinion
# 0        0         0          0        0      5    15           0
# 1        1         0          0        0      4    11           0
# 2        0         0          0        0      6    14           0
# 3        0         0          1        0      3    12           1
# 4        0         0          0        0      3    12           0
#
# [5 rows x 23 columns]

# %%
sports.tail()
# Out:
#    Year  Football  Basketball  Baseball  Soccer  Ice hockey  Auto racing  \
# 2  2008        41           9        10       3           4            3
# 3  2007        43          11        13       2           4            3
# 4  2006        43          12        11       2           2            4
# 5  2005        34          12        12       3           4            5
# 6  2004        37          13        10       2           3            5
#
#    Tennis  Golf  Volleyball  ...  Ice/Figure skating  Rodeo  Track and field  \
# 2       1     2           1  ...                   1      0                0
# 3       1     2           0  ...                   2      0                0
# 4       1     3           0  ...                   3      0                0
# 5       3     2           1  ...                   3      1                0
# 6       2     2           0  ...                   4      1                0
#
#    Fishing  Swimming  Wrestling  Bowling  Other  None  No opinion
# 2        0         0          0        0      6    14           0
# 3        0         0          1        0      3    12           1
# 4        0         0          0        0      3    12           0
# 5        1         0          1        0      4    13           0
# 6        0         0          1        0      4    12           1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Time to make some plots
#
# **4. Plot the percentage of people that say soccer is their favorite sport over time. Give this plot a descriptive title and axis labels. Interpret this plot - what information/insight do you get from this plot?**

# %%
# soccer = sports.sort_values(by = 'Soccer', ascending=False)
# soccer

sum_row = sports.loc[:, sports.columns != "Year"].sum(axis=1)

soccer_percent = (sports['Soccer']/ sum_row) * 100
soccer_percent

plt.bar(sports['Year'], soccer_percent)

plt.xlabel("Year")

plt.ylabel("Percentage");

# %%
soccer_percent
# Out:
# 0    7.142857
# 1    4.081633
# 2    3.061224
# 3    2.000000
# 4    2.020202
# 5    3.000000
# 6    2.000000
# dtype: float64

# %%
percentages = ((sports.loc[:, sports.columns != 'Year']/(sports.loc[:].sum()))) * 100
percentage
# Out:
#         Year   Football  Basketball   Baseball     Soccer  Ice hockey  \
# 0  14.345661  13.503650       13.75  11.392405  30.434783   16.666667
# 1  14.317212  14.233577       15.00  17.721519  17.391304   12.500000
# 2  14.281650  14.963504       11.25  12.658228  13.043478   16.666667
# 3  14.274538  15.693431       13.75  16.455696   8.695652   16.666667
# 4  14.267425  15.693431       15.00  13.924051   8.695652    8.333333
# 5  14.260313  12.408759       15.00  15.189873  13.043478   16.666667
# 6  14.253201  13.503650       16.25  12.658228   8.695652   12.500000
#
#    Auto racing     Tennis       Golf  Volleyball  ...  Ice/Figure skating  \
# 0     8.333333  15.384615   7.142857   33.333333  ...            6.666667
# 1     8.333333  23.076923  14.285714    0.000000  ...            6.666667
# 2    12.500000   7.692308  14.285714   33.333333  ...            6.666667
# 3    12.500000   7.692308  14.285714    0.000000  ...           13.333333
# 4    16.666667   7.692308  21.428571    0.000000  ...           20.000000
# 5    20.833333  23.076923  14.285714   33.333333  ...           20.000000
# 6    20.833333  15.384615  14.285714    0.000000  ...           26.666667
#
#    Rodeo  Track and field  Fishing  Swimming  Wrestling  Bowling      Other  \
# 0    0.0              0.0      0.0       NaN   0.000000      NaN  17.241379
# 1    0.0            100.0     50.0       NaN   0.000000      NaN  13.793103
# 2    0.0              0.0      0.0       NaN   0.000000      NaN  20.689655
# 3    0.0              0.0      0.0       NaN  33.333333      NaN  10.344828
# 4    0.0              0.0      0.0       NaN   0.000000      NaN  10.344828
# 5   50.0              0.0     50.0       NaN  33.333333      NaN  13.793103
# 6   50.0              0.0      0.0       NaN  33.333333      NaN  13.793103
#
#         None  No opinion
# 0  16.853933         0.0
# 1  12.359551         0.0
# 2  15.730337         0.0
# 3  13.483146        50.0
# 4  13.483146         0.0
# 5  14.606742         0.0
# 6  13.483146        50.0
#
# [7 rows x 23 columns]

# %% [markdown]
# > **Interpretation:**

# %% [markdown]
# **4. Plot a bar chart of all of the sports and the percentage of people who say that was their favorite sport in 2017. Give this plot a descriptive title and axis labels. Interpret this plot - what information/insight do you get from this plot?**
#
# *Hint:* You may need to access the column names here!

# %% [markdown]
# > **Interpretation:**

# %% [markdown]
# **Bonus**: Sort the above plot so that the bars are in descending order (highest percentage/largest bar to lowest percentage/smallest bar). Make sure the labels match up!

# %% [markdown]
# **5. Advanced: Graph the popularity over time of two different sports on the same plot. Give this plot a descriptive title and axis labels. Make this plot look as visually appealing as possible. Interpret this plot - what information/insight do you get from this plot?**

# %% [markdown]
# > **Interpretation:**
